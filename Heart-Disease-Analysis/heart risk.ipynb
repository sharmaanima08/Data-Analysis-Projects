# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Data_Heart Problem_risk.csv")
df
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 0        0   64        2.0   F        YES         3.0     0.0
# 1        1   36        4.0   M         NO         0.0     0.0
# 2        2   46        1.0   F        YES        10.0     0.0
# 3        3   50        1.0   M        YES        20.0     0.0
# 4        4   64        1.0   F        YES        30.0     0.0
# ...    ...  ...        ...  ..        ...         ...     ...
# 3385  3385   60        1.0   F         NO         0.0     0.0
# 3386  3386   46        1.0   F         NO         0.0     0.0
# 3387  3387   44        3.0   M        YES         3.0     0.0
# 3388  3388   60        1.0   M         NO         0.0     NaN
# 3389  3389   54        3.0   F         NO         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    221.0  148.0   85.0    NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.shape
# Out:
# (3390, 17)

# %%
df.isna()
# Out:
#          id    age  education    sex  is_smoking  cigsPerDay  BPMeds  \
# 0     False  False      False  False       False       False   False
# 1     False  False      False  False       False       False   False
# 2     False  False      False  False       False       False   False
# 3     False  False      False  False       False       False   False
# 4     False  False      False  False       False       False   False
# ...     ...    ...        ...    ...         ...         ...     ...
# 3385  False  False      False  False       False       False   False
# 3386  False  False      False  False       False       False   False
# 3387  False  False      False  False       False       False   False
# 3388  False  False      False  False       False       False    True
# 3389  False  False      False  False       False       False   False
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# ...

# %%
df.isna().sum()
# Out:
# id                   0
# age                  0
# education           87
# sex                  0
# is_smoking           0
# cigsPerDay          22
# BPMeds              44
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             38
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %%
cf=(df.isna().sum()/len(df))*100
cf
# Out:
# id                 0.000000
# age                0.000000
# education          2.566372
# sex                0.000000
# is_smoking         0.000000
# cigsPerDay         0.648968
# BPMeds             1.297935
# prevalentStroke    0.000000
# prevalentHyp       0.000000
# diabetes           0.000000
# totChol            1.120944
# sysBP              0.000000
# diaBP              0.000000
# BMI                0.412979
# heartRate          0.029499
# glucose            8.967552
# TenYearCHD         0.000000
# dtype: float64

# %%
#analyzed data its missing and null values used methods to treat the values respectively

# %%
df['education'].fillna(df['education'].mode()[0],inplace= True)

# %%
df['cigsPerDay'].fillna(df['cigsPerDay'].median(),inplace= True)

# %%
df['BPMeds'].fillna(0,inplace= True)

# %%
df['totChol'].fillna(df['totChol'].mean(),inplace= True)

# %%
df['BMI'].fillna(df['BMI'].median(),inplace= True)

# %%
df['heartRate'].fillna(df['heartRate'].mean(),inplace= True)

# %%
df['glucose'].fillna(df['glucose'].mean(),inplace= True)

# %%
df.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
np.mean(df["sysBP"])
# Out:
# 132.60117994100295

# %%
np.mean(df["diaBP"])
# Out:
# 82.8830383480826

# %%
np.mean(df["heartRate"])
# Out:
# 75.97727943346119

# %%
np.mean(df["diabetes"])
# Out:
# 0.02566371681415929

# %%
np.mean(df["BMI"])
# Out:
# 25.793250737463126

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   education        3303 non-null   float64
#  3   sex              3390 non-null   object
#  4   is_smoking       3390 non-null   object
#  5   cigsPerDay       3368 non-null   float64
#  6   BPMeds           3346 non-null   float64
#  7   prevalentStroke  3390 non-null   int64
#  8   prevalentHyp     3390 non-null   int64
#  9   diabetes         3390 non-null   int64
#  10  totChol          3352 non-null   float64
#  11  sysBP            3390 non-null   float64
#  12  diaBP            3390 non-null   float64
#  13  BMI              3376 non-null   float64
#  14  heartRate        3389 non-null   float64
#  15  glucose          3086 non-null   float64
# ...

# %%
#dividing age into 2 groups adult and old age. [done]
#dividing sex into 2 groups male and female. [done]
#diving is_smoking into 2 groups smokers and non-smokers. [done]
#dividing cigsPerDay into low , moderate and high consumption. [done]
#dividing BPMeds into taking and not taking. [done]
#dividing prevalentStroke into occured and not occured.[done] 
#dividing prevalentHyp into occured and not occured. [done]
#taking mean of diabetes and analysing and comparing with normal range and putting into 2 categories diabetic and non diabetic.
#taking mean of totChol and analysing and comparing with normal range and putting into 3 categories normalChol , borderline high and high Chol.
#taking mean of sysBP and analysing and comparing with normal range and putting into 3 categpoies normal , high and elevated.
#taking mean of diaBP and analysing and comparing with normal range and putting into 2 categpoies normal , high.
#taking mean of BMI and analysing and comparing with normal range and making 3 categories underweight , healthy and overweight.
#taking mean of heartRate and analysing and comparing with normal range and putting into 3 categories normal , bradycardia(low) and tachycardia(high).
#taking mean of glucose and analysing and comparing with normal range and putting into 3 categories normal , prediabetes and diabetes.
#dividing TenYearCHD into 2 groups positive and negative.

# %%
np.mean(df["glucose"])
# Out:
# 82.08651976668827

# %%
np.mean(df["totChol"])
# Out:
# 237.07428400954655

# %%
df['age_group']=df['age'].apply(
    lambda x: 'Middle Age' if 39<x<51 else ('Adult' if x<=59 else 'Old Age')
)
print(df[['age','age_group']].head(5))
# Out:
#    age   age_group
# 0   64     Old Age
# 1   36       Adult
# 2   46  Middle Age
# 3   50  Middle Age
# 4   64     Old Age

# %%
df['age_group'].value_counts()
# Out:
# age_group
# Middle Age    1431
# Adult         1402
# Old Age        557
# Name: count, dtype: int64

# %%
df['sex_group']=df['sex'].apply(
    lambda x: 'Male' if x=="M" else 'Female')
print(df[['sex_group','sex']].head(5))
# Out:
#   sex_group sex
# 0    Female   F
# 1      Male   M
# 2    Female   F
# 3      Male   M
# 4    Female   F

# %%
df['sex_group'].value_counts()
# Out:
# sex_group
# Female    1923
# Male      1467
# Name: count, dtype: int64

# %%
df['smokers']=df['is_smoking'].apply(
    lambda x: 'Smoker' if x=="YES" else 'Non Smoker')

# %%
df['smokers'].value_counts()
# Out:
# smokers
# Non Smoker    1703
# Smoker        1687
# Name: count, dtype: int64

# %%
df['cig_count']=df['cigsPerDay'].apply(
    lambda x: 'Low' if x<=10 else ('Moderate' if x<30 else 'High')
)

# %%
df['cig_count'].value_counts()
# Out:
# cig_count
# Low         2199
# Moderate     854
# High         337
# Name: count, dtype: int64

# %%
df['BP_meds_consumption']=df['BPMeds'].apply(
    lambda x: 'Not Taking' if x==0 else 'Taking')

# %%
df['BP_meds_consumption'].value_counts()
# Out:
# BP_meds_consumption
# Not Taking    3290
# Taking         100
# Name: count, dtype: int64

# %%
df['stroke']=df['prevalentStroke'].apply(
    lambda x: 'Not Occured' if x==0 else 'Occured')

# %%
df['stroke'].value_counts()
# Out:
# stroke
# Not Occured    3368
# Occured          22
# Name: count, dtype: int64

# %%
df['hyp']=df['prevalentHyp'].apply(
    lambda x: 'Not Occured' if x==0 else 'Occured')

# %%
df['hyp'].value_counts()
# Out:
# hyp
# Not Occured    2321
# Occured        1069
# Name: count, dtype: int64

# %%
df['diabetic']=df['diabetes'].apply(
    lambda x: 'Non diabetic' if x==0 else 'Diabetic')

# %%
df['diabetic'].value_counts()
# Out:
# diabetic
# Non diabetic    3303
# Diabetic          87
# Name: count, dtype: int64

# %%
df['cholesterol']=df['totChol'].apply(
    lambda x: 'Normal' if x<200 else ('Borderline High' if 200<x<239 else 'High'))

# %%
chol_counts=df['cholesterol'].value_counts()
print(chol_counts)
# Out:
# cholesterol
# High               1625
# Borderline High    1102
# Normal              663
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
plt.pie(chol_counts, labels=chol_counts.index, autopct='%d%%' ,colors=['red','yellow','green'])
plt.title('Cholesterol Category Distribution')
plt.show()

# %%
df['systolic_BP']=df['sysBP'].apply(
    lambda x: 'Normal' if x<120 else ('Elevated' if 120<x<130 else 'High')
)

# %%
df['systolic_BP'].value_counts()
# Out:
# systolic_BP
# High        1715
# Normal      1015
# Elevated     660
# Name: count, dtype: int64

# %%
df['diastolic_BP']=df['diaBP'].apply(
    lambda x: 'Normal' if x<80 else 'High'
)

# %%
df['diastolic_BP'].value_counts()
# Out:
# diastolic_BP
# High      2056
# Normal    1334
# Name: count, dtype: int64

# %%
df['_BMI']=df['BMI'].apply(
    lambda x: 'Underweight' if x<18.5 else ('Normal' if 18.5<x<25 else 'Overweight')
)

# %%
df['_BMI'].value_counts()
# Out:
# _BMI
# Overweight     1837
# Normal         1512
# Underweight      41
# Name: count, dtype: int64

# %%
df['HeartRate']=df['heartRate'].apply(
    lambda x: 'Normal' if 60<x<100  else('Bradycardia' if x<60 else 'Tachycardia')
)

# %%
df['HeartRate'].value_counts()
# Out:
# HeartRate
# Normal         2894
# Tachycardia     342
# Bradycardia     154
# Name: count, dtype: int64

# %%
df['Glucose']=df['glucose'].apply(
    lambda x: 'Normal' if x<100 else ('Prediabetes' if 100<x<125 else 'Diabetes')
)

# %%
df['Glucose'].value_counts()
# Out:
# Glucose
# Normal         3103
# Prediabetes     184
# Diabetes        103
# Name: count, dtype: int64

# %%
df['TenYear_CHD']=df['TenYearCHD'].apply(
    lambda x: 'Positive' if x==0 else 'Negative')

# %%
df['TenYear_CHD'].value_counts()
# Out:
# TenYear_CHD
# Positive    2879
# Negative     511
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 id          age    education   cigsPerDay       BPMeds  \
# count  3390.000000  3390.000000  3303.000000  3368.000000  3346.000000
# mean   1694.500000    49.542183     1.970936     9.069477     0.029886
# std     978.753033     8.592878     1.019081    11.879078     0.170299
# min       0.000000    32.000000     1.000000     0.000000     0.000000
# 25%     847.250000    42.000000     1.000000     0.000000     0.000000
# 50%    1694.500000    49.000000     2.000000     0.000000     0.000000
# 75%    2541.750000    56.000000     3.000000    20.000000     0.000000
# max    3389.000000    70.000000     4.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol       sysBP  \
# count      3390.000000   3390.000000  3390.000000  3352.000000  3390.00000
# mean          0.006490      0.315339     0.025664   237.074284   132.60118
# std           0.080309      0.464719     0.158153    45.247430    22.29203
# ...

# %%
#target variable is TenYearCHD
plt.figure(figsize=(5,4))
sns.countplot(x="TenYearCHD" , data=df , palette='pastel')
plt.title("Heart Risk Tendency")
plt.xlabel("Ten Year CHD (0 = no risk , 1 = risk)")
plt.ylabel("Count")
plt.show()

# %%
#age distribuation
plt.figure(figsize=(6,4))
sns.histplot(df['age_group'] , bins=10 , color='skyblue')
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution")
plt.show()

# %%
#gender vs heart disease
plt.figure(figsize=(6,4))
a=sns.countplot(x=df['sex'] , hue=df['TenYearCHD'], palette='pastel')
plt.title("Gender vs Heart Disease Tendency")
plt.xlabel("Gender")
plt.ylabel("Count")
for i in a.containers:
    a.bar_label(i)
plt.show()

# %%
plt.figure(figsize=(6,4))
a=sns.countplot(x="is_smoking" , hue="TenYearCHD" , data=df , palette='pastel')
plt.title("Smoking vs Heart Disease Distribution")
plt.xlabel("Smoking Status")
plt.ylabel("Count")
for i in a.containers:
    a.bar_label(i)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['cigsPerDay'] , bins=10 , color='skyblue')
plt.title("Ciggeretes Per Day Distribution")
plt.xlabel("Ciggeretes Per Day")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,10))
sns.boxplot(x='TenYearCHD' , y='totChol' , data=df , palette='pastel')
plt.title("Cholestrol vs Heart Disease Risk")
plt.xlabel("Heart Disease Risk")
plt.ylabel("Systolic BP")
plt.show()

# %%
plt.figure(figsize=(8,10))
sns.boxenplot(x="TenYearCHD",y="sysBP", data=df , palette='pastel' )
plt.title("SysBP vs Heart Disease Risk")
plt.xlabel("Heart Disease Risk")
plt.ylabel("Systolic BP")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["BMI"] , bins=10 , color='skyblue')
plt.title("BMI Distribution")
plt.xlabel("BMI")
plt.ylabel("Count")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
corr = numeric_df.corr()

plt.figure(figsize=(20,10))
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt='.2f')
plt.title("Correlation Heatmap (with Encoded Categorical Variables)")
plt.show()

# %%
num_cols = ['age', 'totChol', 'sysBP', 'diaBP', 'BMI', 'heartRate', 'glucose']

for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], bins=20, color='skyblue')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
cat_cols = ['sex', 'is_smoking', 'prevalentHyp', 'diabetes', 'BPMeds', 'TenYearCHD']

for col in cat_cols:
    plt.figure(figsize=(5,4))
    sns.countplot(x=col, data=df, palette='Set2')
    plt.title(f"Count of {col}")
    plt.show()

# %%
num_cols = ['age', 'totChol', 'sysBP', 'BMI', 'glucose']

for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='TenYearCHD', y=col, data=df, palette='coolwarm')
    plt.title(f"{col} vs Heart Disease Risk")
    plt.xlabel("Heart Disease Risk (1=Yes, 0=No)")
    plt.ylabel(col)
    plt.show()

# %%
cat_cols = ['sex', 'is_smoking', 'prevalentHyp', 'diabetes']

for col in cat_cols:
    plt.figure(figsize=(6,4))
    ax=sns.countplot(x=col, hue='TenYearCHD', data=df, palette='Set1')
    plt.title(f"{col} vs Heart Disease Risk")
    for container in ax.containers:
        ax.bar_label(container)
plt.show()

# %%
plt.figure(figsize=(6,4))
ax=sns.countplot(x='sex', hue='is_smoking', data=df, palette='Set1')
plt.title("sex vs smokers")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
plt.figure(figsize=(6,4))
a=sns.countplot(x='sex', hue='TenYearCHD', data=df, palette='Set1')
for i in a.containers:
    a.bar_label(i)
plt.show()

# %%
# Encode categorical columns first
df_corr = df.copy()
df_corr['sex'] = df_corr['sex'].map({'M':1, 'F':0})
df_corr['is_smoking'] = df_corr['is_smoking'].map({'YES':1, 'NO':0})

plt.figure(figsize=(20,10))
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='age', y='sysBP', hue='TenYearCHD', data=df, palette='coolwarm')
plt.title("Age vs Systolic BP colored by Heart Disease Risk")
plt.show()

# %%
df['sex'] = df['sex'].map({'M': 1, 'F': 0})
df['is_smoking'] = df['is_smoking'].map({'YES': 1, 'NO': 0})

# %%
sns.pairplot(
    df,
    vars=['age', 'totChol', 'sysBP', 'BMI', 'glucose'],
    hue='TenYearCHD',
    palette='coolwarm'
)
plt.suptitle("Pairwise Relationships Between Features", y=1.02)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.barplot(x='sex', y='TenYearCHD', hue='is_smoking', data=df, palette='Set2')
plt.title("CHD Risk by Sex and Smoking Status")
plt.xlabel("Sex (1=Male, 0=Female)")
plt.ylabel("Average CHD Risk")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='is_smoking', y='sysBP', hue='sex', data=df, palette='Set3')
plt.title("Systolic BP by Smoking Status and Sex")
plt.show()

# %%
pd.crosstab([df['sex'], df['is_smoking']], df['TenYearCHD'], normalize='index') * 100
# Out:
# TenYearCHD              0          1
# sex is_smoking
# 0   0           87.183958  12.816042
#     1           88.144330  11.855670
# 1   0           83.992806  16.007194
#     1           79.912184  20.087816

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# Select numeric features
X = df[['age','totChol','sysBP','diaBP','BMI','glucose','is_smoking','sex','diabetes','prevalentHyp']]
y = df['TenYearCHD']

# Scale and fit model
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

model = LogisticRegression()
model.fit(X_scaled, y)

# Display feature importance
importance = pd.DataFrame({'Feature': X.columns, 'Importance': abs(model.coef_[0])})
importance.sort_values(by='Importance', ascending=False)
# Out:
#         Feature  Importance
# 0           age    0.524650
# 2         sysBP    0.360859
# 7           sex    0.283926
# 6    is_smoking    0.247117
# 5       glucose    0.195621
# 1       totChol    0.115892
# 9  prevalentHyp    0.096719
# 3         diaBP    0.081677
# 4           BMI    0.009824
# 8      diabetes    0.008451

# %%
df.isna().sum()
# Out:
# id                 0
# age                0
# education          0
# sex                0
# is_smoking         0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv("Data_Heart Problem_risk.csv")

# -----------------------------
# 🧹 Step 1: Clean categorical values
# -----------------------------
# Convert to uppercase and remove spaces (handles "yes ", " No", etc.)
df['sex'] = df['sex'].astype(str).str.strip().str.upper()
df['is_smoking'] = df['is_smoking'].astype(str).str.strip().str.upper()

# -----------------------------
# 🔢 Step 2: Encode categorical columns
# -----------------------------
df['sex'] = df['sex'].map({'M': 1, 'F': 0})
df['is_smoking'] = df['is_smoking'].map({'YES': 1, 'NO': 0})

# -----------------------------
# 🧩 Step 3: Fill missing values
# -----------------------------
df.fillna(df.mean(numeric_only=True), inplace=True)

# Fill remaining categorical NaNs (if any)
for col in df.select_dtypes(include='object').columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
from scipy import stats
df = df[(np.abs(stats.zscore(df[num_cols])) < 3).all(axis=1)]

# %%
for col in ['age','totChol','sysBP','BMI','glucose']:
    plt.figure(figsize=(6,4))
    sns.kdeplot(df[df['TenYearCHD']==0][col], label='No CHD')
    sns.kdeplot(df[df['TenYearCHD']==1][col], label='CHD', color='red')
    plt.title(f"Distribution of {col} by Heart Disease Status")
    plt.legend()
    plt.show()

# %%
sns.catplot(x='is_smoking', y='TenYearCHD', hue='sex', col='prevalentHyp', 
            data=df, kind='bar', height=4, aspect=1)
plt.suptitle("Interaction: Smoking, Sex & Hypertension vs CHD", y=1.05)
plt.show()

# %%
df.to_csv('Cleaned_Heart_Risk.csv' , index=False)
